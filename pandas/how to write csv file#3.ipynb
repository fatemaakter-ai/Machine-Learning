# %% [markdown]
# # how to write csv file#3

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\ASUS\\Downloads\\Fortune_10.csv")
df
# Out:
#    ID Data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4  yes         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill               Health       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7   no          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9   no          Ganzlax          IT Services       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.head()
# Out:
#    ID Data             Name            Industry  Inception       Revenue  \
# 0   1  yes          Lamtone         IT Services       2009  $11,757,018
# 1   2  yes        Stripfind  Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation              Health       2012  $10,597,009
# 3   4  yes         Mattouch         IT Services       2013  $14,026,934
# 4   5  yes        Techdrill              Health       2009  $10,573,990
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%

# %%
df.head(10)
# Out:
#    ID Data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4  yes         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill               Health       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7   no          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9   no          Ganzlax          IT Services       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.tail()
# Out:
#    ID Data            Name             Industry  Inception       Revenue  \
# 5   6   no        Techline               Health       2006  $13,898,119
# 6   7   no         Cityace               Health       2010   $9,254,614
# 7   8   no  Kayelectronics               Health       2009   $9,451,943
# 8   9   no         Ganzlax          IT Services       2011  $14,001,180
# 9  10   no     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%
# 8                NaN  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
df.tail(7)
# Out:
#    ID Data            Name             Industry  Inception       Revenue  \
# 3   4  yes        Mattouch          IT Services       2013  $14,026,934
# 4   5  yes       Techdrill               Health       2009  $10,573,990
# 5   6   no        Techline               Health       2006  $13,898,119
# 6   7   no         Cityace               Health       2010   $9,254,614
# 7   8   no  Kayelectronics               Health       2009   $9,451,943
# 8   9   no         Ganzlax          IT Services       2011  $14,001,180
# 9  10   no     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 3  7,429,377 Dollars   6597557    26%
# 4  7,435,363 Dollars   3138627     8%
# 5  5,470,303 Dollars   8427816    23%
# 6  6,249,498 Dollars   3005116     6%
# 7  3,878,113 Dollars   5573830     4%
# 8                NaN  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
df=pd.read_csv("C:\\Users\\ASUS\\Downloads\\Fortune_10.csv", dtype={'ID':'float32'})
df
# Out:
#      ID Data             Name             Industry  Inception       Revenue  \
# 0   1.0  yes          Lamtone          IT Services       2009  $11,757,018
# 1   2.0  yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3.0  yes  Canecorporation               Health       2012  $10,597,009
# 3   4.0  yes         Mattouch          IT Services       2013  $14,026,934
# 4   5.0  yes        Techdrill               Health       2009  $10,573,990
# 5   6.0   no         Techline               Health       2006  $13,898,119
# 6   7.0   no          Cityace               Health       2010   $9,254,614
# 7   8.0   no   Kayelectronics               Health       2009   $9,451,943
# 8   9.0   no          Ganzlax          IT Services       2011  $14,001,180
# 9  10.0   no      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# ...

# %%
df=pd.read_csv("C:\\Users\\ASUS\\Downloads\\Fortune_10.csv", dtype={'Profit':'float64'})
df
# Out:
#    ID Data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4  yes         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill               Health       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7   no          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9   no          Ganzlax          IT Services       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses      Profit Growth
# 0  6,482,465 Dollars   5274553.0    30%
# 1    916,455 Dollars  11412916.0    20%
# 2  7,591,189 Dollars   3005820.0     7%
# ...

# %%
df=pd.read_csv("C:\\Users\\ASUS\\Downloads\\Fortune_10.csv", dtype={'Inception':'str'})
df
# Out:
#    ID Data             Name             Industry Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services      2009  $11,757,018
# 1   2  yes        Stripfind   Financial Services      2010  $12,329,371
# 2   3  yes  Canecorporation               Health      2012  $10,597,009
# 3   4  yes         Mattouch          IT Services      2013  $14,026,934
# 4   5  yes        Techdrill               Health      2009  $10,573,990
# 5   6   no         Techline               Health      2006  $13,898,119
# 6   7   no          Cityace               Health      2010   $9,254,614
# 7   8   no   Kayelectronics               Health      2009   $9,451,943
# 8   9   no          Ganzlax          IT Services      2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services      2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Data', 'Name', 'Industry', 'Inception', 'Revenue', 'Expenses',
#        'Profit', 'Growth'],
#       dtype='object')

# %%
df=pd.read_csv("C:\\Users\\ASUS\\Downloads\\Fortune_10.csv",true_values = ['yes'])
df
# Out:
#    ID Data             Name             Industry  Inception       Revenue  \
# 0   1  yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3  yes  Canecorporation               Health       2012  $10,597,009
# 3   4  yes         Mattouch          IT Services       2013  $14,026,934
# 4   5  yes        Techdrill               Health       2009  $10,573,990
# 5   6   no         Techline               Health       2006  $13,898,119
# 6   7   no          Cityace               Health       2010   $9,254,614
# 7   8   no   Kayelectronics               Health       2009   $9,451,943
# 8   9   no          Ganzlax          IT Services       2011  $14,001,180
# 9  10   no      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Data', 'Name', 'Industry', 'Inception', 'Revenue', 'Expenses',
#        'Profit', 'Growth'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ID         10 non-null     int64
#  1   Data       10 non-null     object
#  2   Name       10 non-null     object
#  3   Industry   10 non-null     object
#  4   Inception  10 non-null     int64
#  5   Revenue    10 non-null     object
#  6   Expenses   9 non-null      object
#  7   Profit     10 non-null     int64
#  8   Growth     10 non-null     object
# dtypes: int64(3), object(6)
# memory usage: 848.0+ bytes

# %%
df = pd.read_csv("C:\\Users\\ASUS\\Downloads\\Fortune_10.csv", false_values=['yes'])
df
# Out:
#      ID Data             Name             Industry  Inception       Revenue  \
# 0   1.0  yes          Lamtone          IT Services     2009.0  $11,757,018
# 1   2.0  yes        Stripfind   Financial Services     2010.0  $12,329,371
# 2   3.0  yes  Canecorporation               Health     2012.0  $10,597,009
# 3   4.0  yes         Mattouch        not available     2013.0  $14,026,934
# 4   5.0  yes        Techdrill        not available     2009.0  $10,573,990
# 5   6.0   no         Techline                  NaN     2006.0  $13,898,119
# 6   7.0   no          Cityace                  NaN     2010.0   $9,254,614
# 7   8.0   no   Kayelectronics               Health     2009.0   $9,451,943
# 8   NaN   no              NaN                  NaN        NaN           NaN
# 9  10.0   no      Trantraxlax  Government Services     2011.0  $11,088,336
#
#             Expenses      Profit    Growth
# 0  6,482,465 Dollars   5274553.0       30%
# 1    916,455 Dollars  11412916.0       20%
# ...

# %%
df = pd.read_csv("C:\\Users\\ASUS\\Downloads\\Fortune_10.csv", true_values=['yes'], dtype={'Data': bool})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('O') to dtype('bool') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6896\3118578752.py in <module>
# ----> 1 df = pd.read_csv("C:\\Users\\ASUS\\Downloads\\Fortune_10.csv", true_values=['yes'], dtype={'Data': bool})
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
