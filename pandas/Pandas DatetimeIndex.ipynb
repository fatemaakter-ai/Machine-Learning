# %% [markdown]
# # Pandas DatetimeIndex

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\ASUS\\Documents\\STUDENT.csv")
df
# Out:
#          Date  student id  class section  study hrs percentage  rate
# 0    1/1/2022        1001     10       a      10000      6000%    80
# 1    1/2/2022        1002     10       a      11000      8000%    50
# 2    1/3/2022        1001     10       a      12000        70%    50
# 3    1/4/2022        1004     10       c      12000        60%    60
# 4    1/5/2022        1002     10       b      11000        NaN    70
# 5    1/6/2022        1006     11       d      14000        50%    70
# 6    1/7/2022        1007     11       d      15000        60%    90
# 7    1/8/2022        1008     11       a      12000        80%    70
# 8    1/9/2022        1003     11       c      12000        NaN    80
# 9   1/10/2022        1010     11       c      11000        40%    60
# 10  1/11/2022        1008     11       b      11000        60%    80
# 11  1/12/2022        1007     11       b      13000        NaN    60
# 12  1/13/2022        1003     12       d      10000          =    60
# ...

# %%
df.dtypes
# Out:
# Date          object
# student id     int64
# class          int64
# section       object
# study hrs      int64
# percentage    object
# rate           int64
# dtype: object

# %%
df=pd.read_csv("C:\\Users\\ASUS\\Documents\\STUDENT.csv",parse_dates=['Date'])
df
# Out:
#          Date  student id  class section  study hrs percentage  rate
# 0  2022-01-01        1001     10       a      10000      6000%    80
# 1  2022-01-02        1002     10       a      11000      8000%    50
# 2  2022-01-03        1001     10       a      12000        70%    50
# 3  2022-01-04        1004     10       c      12000        60%    60
# 4  2022-01-05        1002     10       b      11000        NaN    70
# 5  2022-01-06        1006     11       d      14000        50%    70
# 6  2022-01-07        1007     11       d      15000        60%    90
# 7  2022-01-08        1008     11       a      12000        80%    70
# 8  2022-01-09        1003     11       c      12000        NaN    80
# 9  2022-01-10        1010     11       c      11000        40%    60
# 10 2022-01-11        1008     11       b      11000        60%    80
# 11 2022-01-12        1007     11       b      13000        NaN    60
# 12 2022-01-13        1003     12       d      10000          =    60
# ...

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# student id             int64
# class                  int64
# section               object
# study hrs              int64
# percentage            object
# rate                   int64
# dtype: object

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp
